# %% [markdown]
# <a href="https://colab.research.google.com/github/VirtualGoat/Twitter-Data-Mining/blob/master/Qualify1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install GetOldTweets3
#Using GOT module as twitter's official API restrict the tweets to a specific number thus preventing the user to download old tweets(> 2 months)
# Out:
# Collecting GetOldTweets3
#   Downloading https://files.pythonhosted.org/packages/ed/f4/a00c2a7c90801abc875325bb5416ce9090ac86d06a00cc887131bd73ba45/GetOldTweets3-0.0.11-py3-none-any.whl
# Collecting pyquery>=1.2.10
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from GetOldTweets3) (4.2.6)
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 cssselect-1.1.0 pyquery-1.4.1

# %%
#Accessing the data that has been stored. 
from google.colab import drive
import pickle
import GetOldTweets3 as got
drive.mount('/content/drive')
DATA_PATH = "/content/drive/My Drive/Colab Notebooks/Internship/Tweet Data/New/Mumbai"
users4=open(DATA_PATH+'/activeuserlist.pickle','rb')
real_tweets3=pickle.load(users4)
users4.close()
print(len(real_tweets3))
lisi=list()

DATA_PATH = "/content/drive/My Drive/Colab Notebooks/Internship/Tweet Data/New/"
users5=open(DATA_PATH+'/nonactivemumbai.pickle','rb')
real_tweets4=pickle.load(users5)
users5.close()
print(len(real_tweets4))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 3422
# 8994

# %%
import multiprocessing 
#Using multiprocessing as it utilizes all the cores of CPU and enables parallel computing. 
crawled=set() #unique elements can only be stored. 
m = multiprocessing.Manager()
q = m.Queue()
for i in real_tweets3[751:1050]:   
  if i not in real_tweets4:   
    q.put(i)
print(q.qsize())
li=dict()
import datetime
'''
Steps for checking: 
--> The usernames have been put in a queue. 
--> Each process will access the usernames and pull the tweet data fo the usernames. 
--> To prevent multiple processes from accessing the same username, te username will be popped once a process accepts the username.
'''
from time import sleep
def check_if_rich(q):  
  t=0
  keywords=['gucci','qatar','emirates','cathay pacific','bawa internation','ibis hotel','trident','ikea','zara','vuitton', 'cartier','hermes','hometown','pepperfry','urban ladder','singapore','america','spain','germany','france','paris','berlin','europe','bali','indonesia','switzerland','australia','malaysia','united kingdom','london','mauritius','maldives','thailand','dubai','netherland','tokyo','japan','canada','new york','california','fransisco','angeles','vegas','miami','florida','usa','bermuda','iceland','denmark','luxembourg','kuwait','hong kong','greece','mercedes','bmw','lexus','jaguar','royce','fortuner','audi','bentley','porsche','ferrari','volvo','triumph','enfield','interceptor','rover','cadillac','maserati','lamborghini','hilfiger','rolex','rado','tissot','giordano','diesel','fossil','guess','kors','calvin klein','heuer','armani','adidas','nike','piguet','blanc','hublot','patek', 'bandra', 'khar', 'mahalaxmi', 'south bombay', 'worli', 'vashi', 'colaba','dadar','malabar','lokhandwala','andheri','powai','juhu','peddar','altamount','parel', 'trident','marriot','itc','oberoi','taj','hyatt','lalit','sahara','four seasons','westin','orchid','kohinoor','fariyas','marine plaza','meluha','rodas','radisson','shalimar','waterstones','ambassador','ramada','mirage']
  while(q.empty()!=True): #Repeat until queue contains some elements.    
    try:
        uname=q.get()     #Queue does not contain unique usernames so a separate set is used to store the crawled usernames 
        print(uname)
        if uname not in crawled:
            print(datetime.datetime.now())
            t=t+1
            print(t)
            count=0
            crawled.add(uname)
            tweetCriteria = got.manager.TweetCriteria().setUsername(uname).setSince("2019-01-01").setUntil("2020-03-10") #Pull yearly tweets
            tweets = got.manager.TweetManager.getTweets(tweetCriteria)      
            for j in tweets:
                if any(word in ((j.text).lower()).split() for word in keywords):  #Checking for the presence of qualifying keywords in tweets.  
                    count=count+1
                    li[uname]=count
            print("Going for next user.")
          
    except:
      print("sleeping...")
      sleep(300)
      continue
  return li
# Out:
# 70

# %%
from concurrent.futures import ProcessPoolExecutor
import time
start_time = time.time()

# with concurrent.futures.ProcessPoolExecutor(7) as executor:
#     future = executor.submit(check_if_rich, q)
#     return_value = future.result()



pool = ProcessPoolExecutor(2)
 
future = pool.submit(check_if_rich, q)
result=future.result()
print("Donee!!")
users5=open(DATA_PATH+'/qualified751to1050.pickle','wb')
real_tweets4=pickle.dump(result,users5)
users5.close()
# Out:
# katranjeet
# 2020-03-26 13:53:37.096073
# 1
# Going for next user.
# MarinePlaza
# 2020-03-26 13:56:03.095996
# 2
# Going for next user.
# lisha230792
# 2020-03-26 13:56:19.673698
# 3
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Alisha230792%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# amorosoarts
# 2020-03-26 14:03:11.183591
# 4
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Aamorosoarts%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# DreamPointed
# 2020-03-26 14:08:11.383625
# 5
# Going for next user.
# Jago_Bharati
# 2020-03-26 14:08:11.930639
# 6
# Going for next user.
# wintersockss
# 2020-03-26 14:08:12.113968
# 7
# Going for next user.
# 2020-03-26 14:08:14.007794
# Akka05338246
# 8
# Going for next user.
# ashwinidamani
# 2020-03-26 14:09:45.542540
# 9
# Going for next user.
# cloudaxishost
# 2020-03-26 14:09:58.075540
# 10
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Acloudaxishost%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# Aniruddha_0
# 2020-03-26 14:19:10.721298
# 11
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Aaniruddha_0%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# RupsaChak
# 2020-03-26 14:24:10.877023
# 12
# Going for next user.
# varshasinghs
# 2020-03-26 14:24:24.930687
# 13
# Going for next user.
# VasaiCity
# 2020-03-26 14:26:29.337947
# 14
# Going for next user.
# Mahesh68603340
# 2020-03-26 14:26:32.636934
# 15
# Going for next user.
# ItsAjayShah
# 2020-03-26 14:26:33.031956
# 16
# Going for next user.
# mumbaiescortss4
# 2020-03-26 14:26:35.633025
# 17
# Going for next user.
# parteek44
# 2020-03-26 14:26:54.003622
# 18
# Going for next user.
# getsnigdha
# 2020-03-26 14:27:03.314920
# 19
# Going for next user.
# Stweeder
# 2020-03-26 14:27:29.910877
# 20
# Going for next user.
# nikhilchhajar
# 2020-03-26 14:27:47.284319
# 21
# Going for next user.
# Wealthymatters
# 2020-03-26 14:28:32.825331
# 22
# Going for next user.
# seriousarchitec
# 2020-03-26 14:28:45.352565
# 23
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Aseriousarchitec%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# budh80
# 2020-03-26 14:35:16.881408
# 24
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Abudh80%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# thezhbinge
# 2020-03-26 14:40:17.140069
# 25
# Going for next user.
# manashfrmmumbai
# 2020-03-26 14:41:28.946374
# 26
# Going for next user.
# UiTV_Connect
# 2020-03-26 14:41:29.694416
# 27
# Going for next user.
# abhay005
# 2020-03-26 14:43:05.541114
# 28
# Going for next user.
# Rootsandleisure
# 2020-03-26 14:43:06.128820
# 29
# Going for next user.
# Adventinternat2
# 2020-03-26 14:43:14.904546
# 30
# Going for next user.
# ahmedaliTOI
# 2020-03-26 14:43:16.989908
# 31
# Going for next user.
# SHIVLINK_RE
# 2020-03-26 14:43:25.942409
# 32
# Going for next user.
# Er_ASP
# 2020-03-26 14:43:26.352991
# 33
# Going for next user.
# Nayantweett
# 2020-03-26 14:44:38.350321
# 34
# Going for next user.
# Avni9876
# 2020-03-26 14:45:00.376087
# 35
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Aavni9876%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# mumbaihy
# 2020-03-26 14:51:24.555897
# 36
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Amumbaihy%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# iBajajGal
# 2020-03-26 14:56:24.803938
# 37
# Going for next user.
# rdsouzas
# 2020-03-26 14:57:03.723765
# 38
# Going for next user.
# rudreshpandey06
# 2020-03-26 14:57:08.232403
# 39
# Going for next user.
# jagadesh_R
# 2020-03-26 14:57:09.233777
# 40
# Going for next user.
# PeekandTweet90
# 2020-03-26 14:57:16.809456
# 41
# Going for next user.
# Arvind865522
# 2020-03-26 14:57:16.984559
# 42
# Going for next user.
# theSchantanu
# 2020-03-26 14:57:20.613443
# 43
# Going for next user.
# 2020-03-26 14:57:25.355727
# Indexia_Finance
# 44
# Going for next user.
# Treniq
# 2020-03-26 14:58:21.944650
# 45
# Going for next user.
# jerryrajrod1
# 2020-03-26 14:58:40.115562
# 46
# Going for next user.
# DrWongz
# 2020-03-26 14:59:10.440959
# 47
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Adrwongz%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# savetps6
# 2020-03-26 15:07:24.992299
# 48
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Asavetps6%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# Channeliam
# 2020-03-26 15:12:25.211142
# 49
# Going for next user.
# mumbai_land
# 2020-03-26 15:13:04.477719
# 50
# Going for next user.
# Aditya_K_Gupta
# 2020-03-26 15:13:07.884540
# 51
# Going for next user.
# rituparnasarm10
# 2020-03-26 15:13:16.259438
# 52
# Going for next user.
# UmeshPatil670
# 2020-03-26 15:15:16.859262
# 53
# Going for next user.
# Dangerouslytal
# 2020-03-26 15:15:17.964626
# 54
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Adangerouslytal%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# MyGeorgeApp
# 2020-03-26 15:23:36.186060
# 55
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Amygeorgeapp%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# EwallSquare
# 2020-03-26 15:28:36.412189
# 56
# Going for next user.
# Aaliyababi
# 2020-03-26 15:28:40.241258
# 57
# Going for next user.
# ar_rujuta
# 2020-03-26 15:28:42.658173
# 58
# Going for next user.
# chairsmumbai
# 2020-03-26 15:28:43.762833
# 59
# Going for next user.
# clocate
# 2020-03-26 15:28:45.073646
# 60
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Aclocate%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# vikasF22
# 2020-03-26 15:39:03.525994
# 61
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Avikasf22%20since%3A2019-01-01%20until%3A2020-03-10&src=typd
# sleeping...
# jigishushah
# 2020-03-26 15:44:03.731711
# 62
# Going for next user.
# bkkrish1
# 2020-03-26 15:44:06.195872
# 63
# Going for next user.
# rajnitandan
# 2020-03-26 15:44:36.635236
# 64
# Going for next user.
# tomar_anamika
# 2020-03-26 15:45:06.865353
# 65
# Going for next user.
# AREAMumbai
# 2020-03-26 15:45:08.894925
# 66
# Going for next user.
# sankkash
# 2020-03-26 15:45:09.405179
# 67
# Going for next user.
# pednekargaurav
# 2020-03-26 15:45:11.461063
# 68
# Going for next user.
# bigbrokerdeals
# 2020-03-26 15:45:14.781668
# 69
# Going for next user.
# tanushreevenkat
# 2020-03-26 15:45:15.382872
# 70
# Going for next user.
# Donee!!

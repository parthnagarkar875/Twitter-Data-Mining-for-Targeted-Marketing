# %%
# !pip install GetOldTweets3

# %%
import GetOldTweets3 as got
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('(sell home thane) OR  (sell property thane) OR  (sell house thane) OR  (sell flat thane) OR  (interior designer thane) OR  (house for sale thane) OR  (flat for sale thane) OR (home appliance thane) OR  (vastu thane) OR (home decorator thane)').setSince("2019-01-01").setUntil("2019-12-31")

tweets = got.manager.TweetManager.getTweets(tweetCriteria)
print(len(tweets))

# %%
from google.colab import drive
import pickle
drive.mount('/content/drive')
DATA_PATH = "/content/drive/My Drive/Colab Notebooks/Internship/Tweet Data/Thane"
real_tweets2=open(DATA_PATH+'/j2.pickle','wb')
real_tweets3=pickle.dump(tweets,real_tweets2)
real_tweets2.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#############################################################################################

# %%
from google.colab import drive
import pickle
drive.mount('/content/drive')
DATA_PATH = "/content/drive/My Drive/Colab Notebooks/Internship/Tweet Data/Mumbai"
real_tweets4=open(DATA_PATH+'/bp.pickle','rb')
real_tweets5=pickle.load(real_tweets4)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(len(real_tweets5))
# Out:
# 1382

# %%
no=['decor','realt','stock','group','article','project','commerc','brick','india','guru','new','market','enterp','vastu','astro','estate','mall','hous','mumbai','sky','room','home','flat','design','interior','furniture','pack','builder','propert','vastu','loan','bank','agen']
se1=set()
for i in real_tweets5:
  # if (i.username).lower() not in no:
    se1.add(i.username)
print(len(se1))
# Out:
# 865

# %%
finalset=set()
for i in se1:
  for j in no:
     if j in i.lower():
       finalset.add(i)

# %%
# for i in finalset:
#   print(i)
print(len(finalset))
# Out:
# 103

# %%
h=se1-finalset
print(len(h))

for i in h:
  print(i)
# Out:
# 767
# bangera_shamita
# PropToq
# RamD72819870
# SujeetSingh82
# vipul2777
# uttamkaul
# shagun__jain
# HusainRif
# Gup_gup_gup04
# JAYESHSVORA
# tea_n_see
# JitendrPanwar
# aruns89
# Ampkmailbox
# shravan_THADANI
# ajoydasgupta
# TeluguReporter
# ragways
# AviGhodke3
# pbhushan1
# budbukbum1
# Sharad9Dubey
# AiyoobAshraf
# Prajapati_Group
# theesmaarkhan
# slightlyTall
# naturaltorque
# kb5006
# Vikasvraut2
# Thekalal
# sachinseosk
# MohitPropbuzz
# SelfRedevelop
# MukulSh75166832
# chaanakya41
# Prof_CallumYork
# Ratinsharma76
# Manvend03129323
# alihusnainsajja
# 336c3d300c3949b
# gopeshkalia
# Spotboye
# surbhi2406
# BeingShamss
# gopalshinde81
# AlliDavies1
# Traluk
# NagpalManoj
# shirsekar2016
# Amitmidha37
# Hkulkarni19
# arjunmodhwadia
# Rakeshjeeinc
# RemaxV21
# TopBusinessNetw
# 1Gugugaga
# Luxuryinteriom1
# immymalik2010
# anil_anl2
# Nidhimehta89
# dudec856
# nasirshah121
# hanif4all
# AchalMunshi
# Irfan08843940
# corevestor
# shishirjha07
# VickramChat
# ...

# %%
# !pip install GetOldTweets3

# %%
for i in range(10):
  for j in range(5,20):
    if j==i:
      break
    else:
      print(j)

# %%
# !pip install GetOldTweets3
# Out:
# Collecting GetOldTweets3
#   Downloading https://files.pythonhosted.org/packages/ed/f4/a00c2a7c90801abc875325bb5416ce9090ac86d06a00cc887131bd73ba45/GetOldTweets3-0.0.11-py3-none-any.whl
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from GetOldTweets3) (4.2.6)
# Collecting pyquery>=1.2.10
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 cssselect-1.1.0 pyquery-1.4.1

# %%
from google.colab import drive
import pickle
import GetOldTweets3 as got
drive.mount('/content/drive')
DATA_PATH = "/content/drive/My Drive/Colab Notebooks/Internship/Usernames/Mumbai"
users4=open(DATA_PATH+'/slot2.pickle','rb')
real_tweets3=pickle.load(users4)
users4.close()
print(len(real_tweets3))
lisi=list()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1425

# %%
import multiprocessing 

crawled=set()
m = multiprocessing.Manager()
q = m.Queue()
for i in real_tweets3[700:1424]:      
    q.put(i)
print(q.qsize())
li=list()
def check_if_rich(q):  
  keywords=['singapore','america','spain','germany','france','paris','berlin','europe','bali','indonesia','switzerland','australia','malaysia','united kingdom','london','mauritius','maldives','thailand','dubai','netherland','tokyo','japan','canada','new york','california','fransisco','angeles','vegas','miami','florida','usa','bermuda','iceland','denmark','luxembourg','kuwait','hong kong','greece','mercedes','bmw','lexus','jaguar','royce','fortuner','audi','bentley','porsche','ferrari','volvo','triumph','enfield','interceptor','rover','cadillac','maserati','lamborghini','hilfiger','rolex','rado','tissot','giordano','diesel','fossil','guess','kors','calvin klein','heuer','armani','adidas','nike','piguet','blanc','hublot','patek', 'bandra', 'khar', 'mahalaxmi', 'south bombay', 'worli', 'vashi', 'colaba','dadar','malabar','lokhandwala','andheri','powai','juhu','peddar','altamount','parel', 'trident','marriot','itc','oberoi','taj','hyatt','lalit','sahara','four seasons','westin','orchid','kohinoor','fariyas','marine plaza','meluha','rodas','radisson','shalimar','waterstones','ambassador','ramada','mirage']
  while(q.empty()!=True):
    try:
        uname=q.get()
        print(uname)
        if uname not in crawled:
            crawled.add(uname)
            tweetCriteria = got.manager.TweetCriteria().setUsername(uname).setSince("2019-01-01").setUntil("2019-12-31")
            tweets = got.manager.TweetManager.getTweets(tweetCriteria)
            print("Crawling User: ",uname)      
            for j in tweets:
                if any(word in ((j.text).lower()).split() for word in keywords):
                    li.append(uname)
                    print(li)
                    print(j.text)
                    break
            print("Going for next user.")
    except:
      continue
  return li
# Out:
# 724

# %%
from concurrent.futures import ProcessPoolExecutor
import time
start_time = time.time()

# with concurrent.futures.ProcessPoolExecutor(7) as executor:
#     future = executor.submit(check_if_rich, q)
#     return_value = future.result()



pool = ProcessPoolExecutor(4)
 
future = pool.submit(check_if_rich, q)
result=future.result()




import tweepy

consumer_key='cQLpKHK4YWoH9DNMePH5OEONf'
consumer_secret= 'FQIA1D48eqALlYvRYuic6dth4gurAcMwCVd0Z8ktDmgtVt9Zec'
access_token='1002268050513575936-nj1aWbVHQZRvVrfaY0GXYlFnKktPeM'
access_token_secret='2e91wc6xyiTvWmHq41LTiCPPKQNjKtple69zOUsWIcXjv'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

pname=list()
for i in result:
    try:
      u=api.get_user(i)
      pname.append(u.name)
    except:
      continue
print("Extracted Usernames: ",pname)


import string
import re
def clean_tweet(tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

clean=list()

mail=['gmail','yahoo','hotmail','rediff']

for i in pname:
  if (any(word in i.lower() for word in mail))==True:  
      clean.append(i.lower())    
  else:
      demo=deEmojify(i)
      cle=clean_tweet(demo)
      cleaned=cle.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation)))
      clean.append(cleaned)

print("After cleaning: ",clean)



no=['decor','realt','digi','acre','resid','stock','group','article','project','commerc','brick','india','guru','new','market', \
    'enterp','vastu','astro','estate','mall','hous','mumbai','sky','room','home','flat','design','interior','furniture','trend', \
    'pack','build','work','propert','vastu','gym','loan','luxury','bloomberg','business','direct','time',\
    'revenue','day','bank','agen','job','minis','corpo','tech', \
    'boss','nation','associat','developer','broth','invest','people','dna','media','break','bombay','lodha','hiranandani']
finalset=set()
for i in clean:
    if any(word in i.lower() for word in no):
        finalset.add(i)

users=set(clean)
h=users-finalset
print("After last cleaning: ",h)



import string
import time
import threading
import urllib
import re
import io
import sys
from time import sleep
import pickle
import pandas as pd


def formats(first, middle, last, domain):
    """
    Create a list of 30 possible email formats combining:
    - First name:          [empty] | Full | Initial |
    - Delimitator:         [empty] |   .  |    _    |    -
    - Last name:           [empty] | Full | Initial |
    """
    list = []
    emails=['gmail','yahoo','rediff','hotmail']

    if any(word in first for word in emails):
        list.append(first)

    elif any(word in middle for word in emails):
        list.append(middle)

    elif any(word in last for word in emails):
        list.append(last)


    elif len(last)==0:
        list.append(first + '@' + domain)                    # first@example.com


    else:
        list.append(first[0] + last + '@' + domain)          # flast@example.com
        list.append(first[0] + '.' + last + '@' + domain)    # f.last@example.com
        list.append(first[0] + '_' + last + '@' + domain)    # f_last@example.com
        list.append(first + '@' + domain)                    # first@example.com
        list.append(first + last + '@' + domain)             # firstlast@example.com
        list.append(first + '.' + last + '@' + domain)       # first.last@example.com
        list.append(first + '_' + last + '@' + domain)       # first_last@example.com
        list.append(first + '-' + last + '@' + domain)       # first-last@example.com

        list.append(first + last[0] + '@' + domain)          # fistl@example.com
        list.append(first + '.' + last[0] + '@' + domain)    # first.l@example.com
        list.append(first + '_' + last[0] + '@' + domain)    # fist_l@example.com
        
        list.append(first[0] + middle + last + '@' + domain)          # fmiddlelast@example.com
        list.append(first[0] + '.' + middle + last + '@' + domain)    # f.middlelast@example.com
        list.append(first[0] + middle + '.' + last + '@' + domain)    # fmiddle.last@example.com
        list.append(first[0] + '_' + middle+ last + '@' + domain)    # f_middlelast@example.com
        list.append(first[0] + middle +'_' + last + '@' + domain)    # fmiddle_last@example.com
        list.append(first + middle+ last + '@' + domain)             # firstmiddlelast@example.com
        list.append(first + middle + '.' + last + '@' + domain)       # firstmiddle.last@example.com
        list.append(first + '.' + middle + last + '@' + domain)       # first.middlelast@example.com
        list.append(first + '_' + middle + last + '@' + domain)       # first_last@example.com
        list.append(first + middle + '_' + last + '@' + domain)       # first_last@example.com
        list.append(first + middle+ last[0] + '@' + domain)          # firstmiddlel@example.com
        list.append(first + '.' + middle +last[0] + '@' + domain)    # first.middlel@example.com
        list.append(first + middle + '.' +last[0] + '@' + domain)    # firstmiddle.l@example.com
        list.append(first + '_' + middle +last[0] + '@' + domain)    # first_middlel@example.com
        list.append(first + middle +'_' + last[0] + '@' + domain)    # firstmiddle_l@example.com        
        
        list.append(last + '@' + domain)                     # last@example.com
        list.append(last + first+ '@' + domain)              # lastfirst@example.com
        list.append(last + '.' + first + '@' + domain)       # last.first@example.com
        list.append(last + '_' + first + '@' + domain)       # last_first@example.com
        list.append(last[0] + '.' + first + '@' + domain)    # l.first@example.com    
        list.append(last[0] + first + '@' + domain)          # lfirst@example.com
        list.append(last + first[0] + '@' + domain)          # lastf@example.com
        list.append(last + '.' + first[0] + '@' + domain)    # last.f@example.com
        list.append(last + '_' + first[0] + '@' + domain)    # last_f@example.com
       
    return(list)



len2=list()
l1=list()
l3=list()
ln=list()

email_list=list()
emails=['gmail.com','yahoo.com','rediff.com','hotmail.com','yahoo.co.in']
for j in emails:
    for i in h:
        try:
            i=i.lower()
            s=i.split()

            if len(s)==2:
                email_list.extend(formats(s[0],'',s[1],j))
                len2.append(i)
            elif len(s)==1:
                email_list.extend(formats(s[0],'','',j))        
                l1.append(i)
            elif len(s)==3:
                email_list.extend(formats(s[0],s[1],s[2],j))    
                l3.append(i)
            elif len(s)>3:
                ln.append(i)
                continue    
        except:
            continue        
    lisi.extend(email_list)
print(len(lisi))

emails1=set(lisi)
print(len(emails1))

ninoo=list(emails1)
nino1=pd.Series(ninoo)

nino1.to_csv("/content/drive/My Drive/Colab Notebooks/Internship/Usernames/Mumbai/slot2_700to1424.csv",index=False,encoding='UTF-8')


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# tanmaykr11480
# Crawling User:  tanmaykr11480
# Going for next user.
# puneet917
# Crawling User:  puneet917
# Going for next user.
# corpsuitesnyc
# Crawling User:  corpsuitesnyc
# Going for next user.
# prashantDocean
# Crawling User:  prashantDocean
# ['prashantDocean']
# 1. Dubai (Burj Khalifa) 2. Kathmandu (Mt.Everest) 3. Beijing (Grand Canal) 4. Washington DC (Library of Congress) #AirtelInternationalRoaming @airtelindia
# Going for next user.
# NITINDA89289941
# Crawling User:  NITINDA89289941
# Going for next user.
# ashutosh2586
# Crawling User:  ashutosh2586
# ['prashantDocean', 'ashutosh2586']
# Haa ye tark wajib laga mujhe. Matlab bharat ki economy ab europe se tay hogi. Thank you
# Going for next user.
# Piyul
# Crawling User:  Piyul
# ['prashantDocean', 'ashutosh2586', 'Piyul']
# And yet, the PM keeps invoking & blaming the Congress! Guess this is called withdrawal symptoms
# Going for next user.
# ComSampuran
# Crawling User:  ComSampuran
# Going for next user.
# prashantpnarkar
# Crawling User:  prashantpnarkar
# Going for next user.
# Barrier_S_D
# Crawling User:  Barrier_S_D
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D']
#  emmanuelle moureaux creates a colorful ‘universe of words’ for installation in tokyo http://dlvr.it/RCWXx4
# Going for next user.
# KARTIKHRAVAL
# Crawling User:  KARTIKHRAVAL
# Going for next user.
# searchresume
# Crawling User:  searchresume
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume']
# Crane Operator Safety in Nagercoil, Tamil Nadu, India: crane, rig, deck, crane operator, diesel https://postjobfree.com/resume/ada58z
# Going for next user.
# CoconutEvent
# Crawling User:  CoconutEvent
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent']
# #CoconutEvent is proud to be associated with ‘REBRANDX’, an initiative by Brand Torque, presented by Siddha Sky, a Sejal-Siddha Project &amp; in association with knowledge partner S P Jain School of Global Management held on 12th July 2019 at ITC Grand Central. #glimpse #events
# Going for next user.
# EleyDemetrius
# Crawling User:  EleyDemetrius
# Going for next user.
# cricket_fundas
# Crawling User:  cricket_fundas
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas']
# LG Electronics to unveil indoor gardening appliance at CES 2020, Las Vegas #LGElectronics #CEC2020 #LasVegas #indoorgardening http://www.business-news-today.com/lg-electronics-to-unveil-indoor-gardening-appliance-at-ces-2020-las-vegas/
# Going for next user.
# officechairsma1
# Crawling User:  officechairsma1
# Going for next user.
# IL_AmbienteInd
# Crawling User:  IL_AmbienteInd
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd']
# On this holy day, we celebrate the valour and courage of Lord Rama and the triumph of good over evil. Interior Lifestyle India by Ambiente India wishes you and your precious families a very Happy and Inspiring Dussehra. #HappyDussehra #Dussehra2019 #GoodOverBad #GoodOverEvil
# Going for next user.
# bou_msa3ad
# Crawling User:  bou_msa3ad
# Going for next user.
# savla_pratham
# Crawling User:  savla_pratham
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham']
# Hahaha okay! Got a little intense I guess Anyways ek hi maradva hai ab India mai. I follow him fully!
# Going for next user.
# AvocaTravels
# Crawling User:  AvocaTravels
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels']
# If you ask avid travelers to draw up a list of their top 10 dream holiday destinations, it would be a safe bet that Spain would feature prominently. http://bit.ly/2nft9Na #spain #madrid #beautifuldestinations #spainphotography #avocatravels
# Going for next user.
# fibre2fashion
# Crawling User:  fibre2fashion
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion']
# #Techtextil North America 2020 Is Here! Early Bird Registration for the biggest and best show for #TechnicalTextiles, #Nonwovens &amp; #Sewn Products has opened! Register today to save BIG! Register Now: https://bit.ly/2OItmCq
# Going for next user.
# soowoodofficial
# Crawling User:  soowoodofficial
# Going for next user.
# davidalka
# Crawling User:  davidalka
# Going for next user.
# sidin
# Crawling User:  sidin
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin']
# Only 60% sure of this. But the first ever voice of Indian musicians recorded on any medium was possibly the voices of a young lawyer and an Indian army doctor recorded in the basement of a shop near the Strand in London in 1899.
# Going for next user.
# GarimaRathi51
# Crawling User:  GarimaRathi51
# Going for next user.
# nealecastelino
# Crawling User:  nealecastelino
# Going for next user.
# StudentUniverse
# Crawling User:  StudentUniverse
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse']
# Tired of the snow already? Grab a flight from New York to Miami for $48* on Jan. 7th → https://hubs.ly/H0m4Nl80
# Going for next user.
# BillionDollarBK
# Crawling User:  BillionDollarBK
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK']
# This brand new villa is the best priced 8 bedroom villa in the Dubai Market... Client wants to sell it Today! For details call or whattsapp T: +971 56 339 5794 #Dubai #DXB #LovinDubai #MyDXB #India #Mumbai #delhi #Saudi #abudhabi #forsale #Home #love #deal
# Going for next user.
# haresh0277
# Crawling User:  haresh0277
# Going for next user.
# shairon_indic
# Crawling User:  shairon_indic
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic']
# Which is this place exactly. Just trying to understand Dubai
# Going for next user.
# renderimage1
# Crawling User:  renderimage1
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1']
# To show your clients your vision of how a medical centre should be, there is no better way than rendering 3D design. Check out more designs at http://www.renderimagestudio.com Image rendered in 3d for New Medical Centre Dubai by @renderimage1 #interior #interiordesign #3d #renderimage
# Going for next user.
# arjula1
# Crawling User:  arjula1
# Going for next user.
# CIIEvents
# Crawling User:  CIIEvents
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents']
# Japan is a mjr partner of India in fostering infra growth & promoting #mfg excellence thru various initiatives. #VLFM is 1 key initiative whr #IndoJapan cooperation is achieving the goal of enhancing #MfgExcellence~Kenjo Akamine, Sr Rep, #JICA India #VLFMSummit2019 #CII4WR
# Going for next user.
# VaibhavHankare5
# Crawling User:  VaibhavHankare5
# Going for next user.
# Yashodhara
# Crawling User:  Yashodhara
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara']
# It is shameful to belong to a city where you showed up casually after visiting RSS in Nagpur. Germany has done so much and bent backwards to remove the traces of fascism yet you are OK in the name of “learning” to do so here?! This is gaslighting if the nastiest kind
# Going for next user.
# BisonPanel
# Crawling User:  BisonPanel
# Going for next user.
# Chal_Rehn_Dy
# Crawling User:  Chal_Rehn_Dy
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy']
# Ap dhundooo mere liye koi germany mn
# Going for next user.
# mdomale_MDA
# Crawling User:  mdomale_MDA
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA']
# MAD explores the future city with centre pompidou exhibition in paris
# Going for next user.
# imlenkagirija
# Crawling User:  imlenkagirija
# Going for next user.
# sandeep_447
# Crawling User:  sandeep_447
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447']
# 1. Dubai 2. Kathmandu 3. Beijing 4. Washington #AirtelInternationalRoaming @sonali31104 @BharatParyatan @OnlySiddhartha @ramyavellanki @itzzmesowju
# Going for next user.
# singhvarun
# Crawling User:  singhvarun
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun']
# Oh isn’t Malaysia the same country which had asked Rohingyas to go back? https://www.google.com/amp/s/amp.theguardian.com/world/2015/may/13/malaysia-tells-thousands-of-rohingya-refugees-to-go-back-to-your-country
# Going for next user.
# vishwagreenreal
# Crawling User:  vishwagreenreal
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal']
# THE ADDRESS. Plan M Situated at Turbhe is the epicenter of expediency. Connectivity to the local stations Turbhe, Vashi is just a few minutes away. Its super connectivity to Thane Belapur-Panvel-Pune expressway makes it effortless for the commuter. #PLANM #VISHWAGREENREALTORS.
# Going for next user.
# timhudson233
# Crawling User:  timhudson233
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233']
# Dadar is one of the best localities in Mumbai where you should buy a house as there are schools, parks, temples, hospitals, and shopping centers in close proximity to residences. For more information visit here. #FlatsinMumbai
# Going for next user.
# pavankorde
# Crawling User:  pavankorde
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde']
# @rpomumbai...Sir please confirm the status of my application submitted on 26/6/2019. PSK Andheri document submitted on 3/7/2019. Police station verification done on 9/7/2019. As I saw on website, normally in MH passport gets delivered in 21 days.
# Going for next user.
# arihant_mattres
# Crawling User:  arihant_mattres
# Going for next user.
# hazratbilli
# Crawling User:  hazratbilli
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli']
# Rado ki ghadi haaton me Itr gucci Wala.
# Going for next user.
# longhandnotes
# Crawling User:  longhandnotes
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes']
# #HindiGrammar sticklers, Does the following line fix the "misprints" in the pictured mural quote from Mumbai's Andheri station? "सपनें वे नहीं जो हम सोते समय देखें, सपनें वे हैं जो हमें सोने न दें ।"
# Going for next user.
# Stephan67231196
# Crawling User:  Stephan67231196
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196']
# @drmbct looks like these people were destroying railway property by breaking the steps of newly constructed railway exit with a hammer, located near the east side exit of Bandra Station next to ticket counter and they don't look like railway workers. Pls check immediately.
# Going for next user.
# shubhpravesh01
# Crawling User:  shubhpravesh01
# Going for next user.
# VasaiCity
# Crawling User:  VasaiCity
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity']
# Lokhandwala Durgotsav — in Lokhandwala Complex https://www.facebook.com/1050435218/posts/10218188757084300/
# Going for next user.
# shaikh_tailor
# Crawling User:  shaikh_tailor
# Going for next user.
# aditya2585
# An error occured during an HTTP request: HTTP Error 503: Service Temporarily Unavailable
# Try to open in browser: https://twitter.com/search?q=%20from%3Aaditya2585%20since%3A2019-01-01%20until%3A2019-12-31&src=typd
# Niva64732295
# Crawling User:  Niva64732295
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295']
# @HomeLoansByHDFC Mumbai Andheri branch where my brother applied home loan, process too slow, people not aware about proper process, about PMAY they were not aware properly, documentation was provided to bank in March, enquired recently they replied claim is ready for filling...
# Going for next user.
# rahul85438855
# Crawling User:  rahul85438855
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855']
# Crane manufacturers supply cranes to construction companies in Kuwait . Now their activities extend across global markets. They've become known not just for the caliber of these machines. http://www.santek.co.in/
# Going for next user.
# ninadrane007
# Crawling User:  ninadrane007
# Going for next user.
# RealitySunteck
# Crawling User:  RealitySunteck
# Going for next user.
# ask_bull
# Crawling User:  ask_bull
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull']
# @PMOIndia @DrSJaishankar @AmitShahOffice A guy named Saravanan Gandhi has posted this violent video against our Hon PM.. He works in Singapore in a company called Econ Precast pte Ltd. Must b an Indian PP holder. Can any action be tkn against him? https://m.facebook.com/story.php?story_fbid=2445696408861886&amp;id=100002646514525
# Going for next user.
# DhanashreeJad15
# Crawling User:  DhanashreeJad15
# Going for next user.
# IIncrediblebulk
# Crawling User:  IIncrediblebulk
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk']
# You now know? Why the CAA? Hope you're eyes open out of nothing, this is what happens out of minority, every little issue is Islamised with a shade of persecution and subjugation. Later once they have the majority, the tables turn. Try your liberal colours in Malabar and tell me
# Going for next user.
# RVO_Int_Ond
# Crawling User:  RVO_Int_Ond
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond']
# Wil je ondernemen in #Japan, of doe je daar al zaken? Met de training 'Get ready for Japan' ben je beter voorbereid op de Japanse markt. Meld je snel aan voor de training van 18 t/m 29 mei in Japan en vergroot je kansen op succes! http://bit.ly/34Uzyyg
# Going for next user.
# OmjiOmprakash
# Crawling User:  OmjiOmprakash
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash']
# Greatest target acheived MANY MANY DIWALI WISHES TO THE GREAT UNITED SATATES OF AMERICA . AND TRUMP COMBACK IN ELECTION TO SERVE USA AND BENIFIT THE WORLD .
# Going for next user.
# SchezwanS
# Crawling User:  SchezwanS
# Going for next user.
# BollySpy
# Crawling User:  BollySpy
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy']
# #KatrinaKaif And #AyanMukerji Spotted At #Dharma Office Khar #Bollywood #BollywoodNews #Bollyspy Watch Video https://youtu.be/V2c0xgp6xHc
# Going for next user.
# sarathi1627
# Crawling User:  sarathi1627
# Going for next user.
# sudhir3943
# Crawling User:  sudhir3943
# Going for next user.
# Simran4Escorts
# Crawling User:  Simran4Escorts
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts']
# Simran Oberoi Mumbai Escorts: High-class independent escorts in Mumbai are very ... https://simranoberoidatinggirl.blogspot.com/2019/10/high-class-independent-escorts-in.html?spref=tw
# Going for next user.
# ruchirao4night1
# Crawling User:  ruchirao4night1
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1']
# Checking out "Private VIP Female Escorts Service in Mumbai" on McDonald Pontiac Cadillac GMC: http://mcdonaldauto.ning.com/profiles/blogs/private-vip-female-escorts-service-in-mumbai
# Going for next user.
# Rajeev43767418
# Crawling User:  Rajeev43767418
# Going for next user.
# priranjank
# Crawling User:  priranjank
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank']
# So, what will be happening next?? Elections in USA to elect new president???
# Going for next user.
# Anandkaaddress2
# Crawling User:  Anandkaaddress2
# Going for next user.
# ojhabawa
# Crawling User:  ojhabawa
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa']
# Premium Studio Apartment on rent at Union Park, Bandra West. Quote - 1.10 lakh. For details contact Vishal - 9820056180 @Bandra West https://www.instagram.com/p/B6QaxrJpxKo/?igshid=lai81meg4j01
# Going for next user.
# shibadurani
# Crawling User:  shibadurani
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani']
# Mrs Confidence Diva 2019 @Novotel Mumbai Juhu Beach https://www.instagram.com/p/BykJtfQFyjn/?igshid=1eqwad2gxyfzz
# Going for next user.
# ProTecDi
# Crawling User:  ProTecDi
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi']
# ¿Como el paisajismo ha dado forma a la vida pública además de definir entorno construido? Plaza Music Center Los Angeles Residencia James Rose &amp; Museo Hirshhorn y jardín de esculturas Centro presidencial Obama #Paisajismo | #Urbanismo | #DespedidaDeAño
# Going for next user.
# SmartKate21
# Crawling User:  SmartKate21
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21']
# Buying a property in Dadar east or anywhere else in Mumbai? Some might suit your requirement but not your budget, some might suit your budget but not make you feel fulfilling. Here are some useful tips that might help you. Visit to know more >
# Going for next user.
# shikhadesai1990
# Crawling User:  shikhadesai1990
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990']
# Here’s what makes Bandra Kurla Complex the best property hub in Mumbai Know more about Rustomjee, CLICK HERE >> https://www.slideserve.com/shikhadesai1990/here-s-what-makes-bandra-kurla-complex-the-best-property-hub-in-mumbai-powerpoint-ppt-presentation #flatsinbandra #apartmentsinbandra #propertyinbandra #flatsinbkc #Propertyinbkc #3bhkflatsinbkc #3bhkflatsinbandraeast
# Going for next user.
# IamSupriyaRK
# Crawling User:  IamSupriyaRK
# Going for next user.
# HinduComrade
# Crawling User:  HinduComrade
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade']
# China has successfully landed a rover on moon. Is building its own space station. How did Chinese become so intelligent than Madrassis? We can't even land rover on moon, but plans to build own space shuttle, own space station. Own moon base.
# Going for next user.
# nitinmd123
# Crawling User:  nitinmd123
# Going for next user.
# DeoPratik
# Crawling User:  DeoPratik
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik']
# Koalas ‘Functionally Extinct’ After Australia Bushfires Destroy 80% Of Their Habitat
# Going for next user.
# AjitGeorge5
# Crawling User:  AjitGeorge5
# Going for next user.
# SHIVLINK_RE
# Crawling User:  SHIVLINK_RE
# Going for next user.
# kamlesm
# Crawling User:  kamlesm
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm']
# Avalokiteshvar Srivijayan Art Srivijaya empire of malay area, what now is malaysia 9th century Bronze sculpture said to be in Bangkok museum Chaiya, Surat Thani, Thailand. Central Java art (Sailendra art) influence. Wiki chintamani samartunga kolthunga chola & others ruled
# Going for next user.
# InvGurInd
# Crawling User:  InvGurInd
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd']
# India may surpass Germany to become world`s fourth-largest economy in 2026: Report http://investmentguruindia.com/TopNews/India-may-surpass-Germany-to-become-worlds-fourth-largest-economy-in-2026-Report #India #Economy #GDP #Germany #Japan
# Going for next user.
# aaamehra
# Crawling User:  aaamehra
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra']
# 2BHK 750 Sq Ft at Andheri West, Mumbai - Well done up 2bhk�Negotiable http://ampropertymall.com
# Going for next user.
# FfscIn
# Crawling User:  FfscIn
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn']
# 15th Governing Council meeitng of FFSC was held in Radisson Blu Plaza, New Delhi. Presentations on Learning to Livelihood, Standards Development, WorldSkills Competition, Engagements and Apprenticeship were followed by interaction sesssions. @MSDESkillIndia @NSDCINDIA #SkillIndia – at The Radisson Blu Plaza
# Going for next user.
# AMARCHANDRAKAN3
# Crawling User:  AMARCHANDRAKAN3
# Going for next user.
# raveena25790171
# Crawling User:  raveena25790171
# Going for next user.
# DilipSi56239462
# Crawling User:  DilipSi56239462
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462']
# mysore i like you please contact me i am dubai
# Going for next user.
# ranaalikash
# An error occured during an HTTP request: <urlopen error [Errno 104] Connection reset by peer>
# Try to open in browser: https://twitter.com/search?q=%20from%3Aranaalikash%20since%3A2019-01-01%20until%3A2019-12-31&src=typd
# FinanzLinksAsia
# Crawling User:  FinanzLinksAsia
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia']
#  Singapore Bourse May Extend Monday's Losses: The Singapore stock market on Monday halted the five-day winning streak in which it had advanced more than 15 points or 0.5 percent. The Straits Times Index now rests just above the 3,220-point plateau… https://www.rttnews.com/story.aspx?Id=3055767 RTT
# Going for next user.
# theabhijoshi
# Crawling User:  theabhijoshi
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi']
# I believe the same is happening in USA to where @realDonaldTrump accuses @cnni for being into fake news...
# Going for next user.
# raviraw96692929
# Crawling User:  raviraw96692929
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi', 'raviraw96692929']
# Mindfields - interior designers in vashi navi mumbai . We have team of highly experienced professionals Interior designers who believe in understanding then executing visit : http://mindfieldsinterior.com/interior-designer-navi-mumbai.html
# Going for next user.
# TeamUpNC
# Crawling User:  TeamUpNC
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi', 'raviraw96692929', 'TeamUpNC']
# Coverage of World Property & Investment Show 2019 from 19th-20th Oct 2019 at Nehru Centre, Worli (Mumbai). in Times of India page no. 9, 18th Oct. 2019 Edition #TeamUP #Deals #PropertyDeals #InternationalProperties #TimesProperty #BestInternationalDeals #WPIS #PropertyExhibition
# Going for next user.
# The_AceTech
# Crawling User:  The_AceTech
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi', 'raviraw96692929', 'TeamUpNC', 'The_AceTech']
# Guess the place. This place is an architectural icon in the city of the Nawabs. This impressive structure stands calmly amid the hustle-bustle of Laad Bazaar of the Old city.
# Going for next user.
# AbhayAgaste
# Crawling User:  AbhayAgaste
# Going for next user.
# Littleshrimpcat
# Crawling User:  Littleshrimpcat
# Going for next user.
# chukkukkapi
# Crawling User:  chukkukkapi
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi', 'raviraw96692929', 'TeamUpNC', 'The_AceTech', 'chukkukkapi']
# Guess the fish :)
# Going for next user.
# genieprop
# Crawling User:  genieprop
# Going for next user.
# adityabagri93
# Crawling User:  adityabagri93
# Going for next user.
# NIIFD2
# Crawling User:  NIIFD2
# Going for next user.
# Chairsbazaar
# Crawling User:  Chairsbazaar
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi', 'raviraw96692929', 'TeamUpNC', 'The_AceTech', 'chukkukkapi', 'Chairsbazaar']
# Aristocrat Sofas . Vashi Navi Mumbai. 9619714777
# Going for next user.
# PlanetStone1
# Crawling User:  PlanetStone1
# Going for next user.
# cvrlifescience
# Crawling User:  cvrlifescience
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi', 'raviraw96692929', 'TeamUpNC', 'The_AceTech', 'chukkukkapi', 'Chairsbazaar', 'cvrlifescience']
# Amazon Unveils Climate Plan, Pledges to Meet Paris Agreement Goals 10 Years Early Washington: Amazon chief Jeff Bezos... https://cvrnewsdirect.com/amazon-unveils-climate-plan-pledges-to-meet-paris-agreement-goals-10-years-early/?feed_id=6805&amp;_unique_id=5d8442ab18b28
# Going for next user.
# RemaxV21
# Crawling User:  RemaxV21
# Going for next user.
# anshu_0803
# An error occured during an HTTP request: HTTP Error 503: Service Temporarily Unavailable
# Try to open in browser: https://twitter.com/search?q=%20from%3Aanshu_0803%20since%3A2019-01-01%20until%3A2019-12-31&src=typd
# buynuse3
# Crawling User:  buynuse3
# ['prashantDocean', 'ashutosh2586', 'Piyul', 'Barrier_S_D', 'searchresume', 'CoconutEvent', 'cricket_fundas', 'IL_AmbienteInd', 'savla_pratham', 'AvocaTravels', 'fibre2fashion', 'sidin', 'StudentUniverse', 'BillionDollarBK', 'shairon_indic', 'renderimage1', 'CIIEvents', 'Yashodhara', 'Chal_Rehn_Dy', 'mdomale_MDA', 'sandeep_447', 'singhvarun', 'vishwagreenreal', 'timhudson233', 'pavankorde', 'hazratbilli', 'longhandnotes', 'Stephan67231196', 'VasaiCity', 'Niva64732295', 'rahul85438855', 'ask_bull', 'IIncrediblebulk', 'RVO_Int_Ond', 'OmjiOmprakash', 'BollySpy', 'Simran4Escorts', 'ruchirao4night1', 'priranjank', 'ojhabawa', 'shibadurani', 'ProTecDi', 'SmartKate21', 'shikhadesai1990', 'HinduComrade', 'DeoPratik', 'kamlesm', 'InvGurInd', 'aaamehra', 'FfscIn', 'DilipSi56239462', 'FinanzLinksAsia', 'theabhijoshi', 'raviraw96692929', 'TeamUpNC', 'The_AceTech', 'chukkukkapi', 'Chairsbazaar', 'cvrlifescience', 'buynuse3']
# Checkout this Royal Enfield classic 350 for sale in Hyderabad on #Buynuse
# Going for next user.
# Bizofit
# Crawling User:  Bizofit
# ...
# wait didn't the retrograde end? @caramelwings said so! I also had to cancel my holiday :( I was supposed to be in Paris in 4 days instead I cannot leave the country so I guess I am binge watching LOTR again next week??
# Going for next user.
# SumitGu84292806
# Crawling User:  SumitGu84292806
# Going for next user.
# Extracted Usernames:  ['Prashant Sharma', 'Ashutosh yadav', 'Piyul Mukherjee', 'Barrier S & D', 'Dennis Gorelik', 'Coconut Event', 'OyeCricket.com', 'Interior Lifestyle India by Ambiente India', 'Pratham Savla', 'Avoca Travels', 'Fibre2Fashion', 'Absolute Scenes, Get In There Lads', 'StudentUniverse', 'Jason Hayes', 'Mr. Shairon', 'renderimage', 'CII Live', '42', 'ɢᴏᴏɢʟᴇ_ᴡᴀꜱ_ᴍʏ_ɪᴅᴇᴀ', 'Magui', 'SANDEEP', 'Singh Varun', 'Vishwa Green Realtor', 'Tim Hudson', 'PAVAN KORDE', 'ShaheenBaugKiBilli \u200fأم القط', 'Arvind Iyer', 'Stephanie Richards', 'Shyam Bhattacharjee', 'Niva', 'Rahul Joshi', 'innocent child', 'Ronnie Budweiser', 'RVO Internationaal', 'Omprakash Dubey (Omji)', 'Bollywood Spy', 'Simranoberoi', '👌 👌 ruchi rao 👌 👌', 'Priyaranjan Kumar', 'Vishal Ojha - Bloom Realty', 'shiba durani', 'ProTecDi', 'Kate Brown', 'shikha', 'HinduComrade', 'Pratik Deo', 'g katyan misra', 'InvestmentGuruIndia', 'Ashok mehra', 'Furniture and Fittings Skill Council', 'Dilip Singh', 'FinanzLinksASIA', 'Abhishek Joshi', 'ravi rawat', 'TeamUp Broker Network Channel', 'ACETECH', 'pins', 'Chairsbazaar.in', 'cvrlifescience', 'Buynuse', 'Biz of IT Innovations', 'Rakesh Shetty', 'Sahyog College', 'Plant People', 'Sekharbiswas ', 'saket साकेत ಸಾಕೇತ್ 🇮🇳', 'Pradnesh Desai', 'mukesh harjani', 'Parag Awasthi', 'mamarahimsalim', 'Horizons Cottages', 'Scarlet Splendour', 'Трезубец Шивы', 'sunil prajapati', 'TheMaddy', 'वीरा', 'Wishkarma.Com', 'Onesite Realty', 'Il Rigattiere Dadaista', 'mstk', 'Rizo Khalifa®', 'TheMorningStandard', 'Cenmax', 'Trust Bandit', 'sshetty', 'Blanche Horst', 'JE&VEE Infrastructure PVT. LTD.', 'whiskeylovin’pundit', 'Jignesh Parekh', 'All_101', 'Sudha Blanc 📚🎨🍍', 'Parveen Kader', 'Prince Polo', 'Brendan Rodrigues', 'Raulf', 'TukdeTukdeofTukdeTukde', 'himniserviceapartments', 'MOHAMMED JABIR HUSSAIN SHAIKH', 'mrsubramani', 'Sachin Jawale', 'Chandrashekhar Upadhyay', 'IndiaBusinessQuiz', 'prabhakar', 'Mateen Hafeez', 'LawHak', 'Cat', 'Oni Sing', 'BASF', 'Nil Frando', 'Bright Angles', 'Hardik', 'Amogh Nayak', 'Sudhir', 'alison mccafferty', 'Anand Sanghvi 🇮🇳', 'Ankit Sadariya 🇮🇳', 'Rashtrapati-Bheem', 'Debabrata Mukherjee', '7WD Design Studio', 'Milind Goraksha', 'Hemant Srivastava', 'S.Phobia', 'محمد\u200e مجهول', 'Pavani B', 'Nedrick Events', 'Livingetc India', 'Good Governance 🇮🇳', 'In Style Woman', 'L̶o̶n̶e̶ Crusader 2.0 🇮🇳', 'RVAIDYA2000', 'Neelesh Bajaj', 'Sudip Joshi', 'Ahlam Galadari', 'MouthShut.com', 'SU Art and Music Histories', 'Jim Stevenson', 'Future World', 'B.S.Purohit', 'Rizwan Shaikh', 'M Almoula', 'Venzo Wood', 'urban hermit', 'Mihir Bijur', 'Shrikant', 'Priyanka Borpujari', '.उpma.', 'Wallpaper*', 'JAGAHA', 'Voice Of Ram', 'Interior Design Addict', 'Tea Lover', 'Ben Waren', 'Myles D Gooding', 'Aliabbas Mundrawala', 'PropCheckup', 'Sukanta Kumar Mishra', 'Premleela Heights', 'Sure Mithas Travel', 'HKTDC', 'Ajay Chaturvedi', 'Dev Chaudhary', 'morphogenesis.', 'Mohammad Iqbal Abid', 'Vishal Vora', 'Navneet sahay', 'Yash Kabra', 'Gobindram Bang', 'Food Cuddle', 'Roberto G. Berlanga', 'Sudhir Parmar', 'myadvtcorner.com', 'ApkGK.Com', 'John🇮🇳', 'Reena Gupta', 'Armyveternal', 'nilu ', 'PAYAL ROHATGI & Team- Bhagwan Ram Bhakts', '🌈 REAL ESTATE CONSULTANT MUMBAI🌈', 'Charles Dsa', 'piyush doshi', 'Baby Llama', 'Kesaria', 'Chaotic Peace|AsimSquad', 'AYAZ Y. KHAN (PAPPU)', 'IP', 'Sujoy Dhar', 'astrologerambajijyotish', 'Ambika Bhatt', 'rituparna bharat sarma', 'Mumtaz Rahebar Khan', 'VAYA Fabrics', 'Pratik Bubna', 'PRABHAT DUBE', 'Ruchika Pal Kaur', 'NDTV Profit', 'rajan sen', 'Ishita Joshi', 'Shraddha Pawar', 'India News 🇮🇳', 'Pritam Biswas', 'Ram Bhimani', 'Namo Etle Saune Gamo', 'Totes McGoats™', 'Anika', 'YourStory', 'askwebm', 'NJ 🌷', 'ભૈરવી', 'Madhuri Bhaduri', 'Kamal Kumar I ❤ KEJRIWAL', 'ilika s thapa', 'LatestLY', 'Gustav Sha', 'Samirr Sirr', 'Hardik Shah', 'Manish Bhatia', 'Wasim Akram 🇮🇳', 'Bagad Billa (Original) 😈👿😈', 'Ashutosh Agarwal', 'cynthia kosciuczyk', 'Post Your Ads Free', 'Antonini Modern Living', 'Abhijit Ch ...
# After cleaning:  ['Prashant Sharma', 'Ashutosh yadav', 'Piyul Mukherjee', 'Barrier S   D', 'Dennis Gorelik', 'Coconut Event', 'OyeCricket com', 'Interior Lifestyle India by Ambiente India', 'Pratham Savla', 'Avoca Travels', 'Fibre2Fashion', 'Absolute Scenes  Get In There Lads', 'StudentUniverse', 'Jason Hayes', 'Mr  Shairon', 'renderimage', 'CII Live', '42', '   ', 'Magui', 'SANDEEP', 'Singh Varun', 'Vishwa Green Realtor', 'Tim Hudson', 'PAVAN KORDE', 'ShaheenBaugKiBilli', 'Arvind Iyer', 'Stephanie Richards', 'Shyam Bhattacharjee', 'Niva', 'Rahul Joshi', 'innocent child', 'Ronnie Budweiser', 'RVO Internationaal', 'Omprakash Dubey  Omji ', 'Bollywood Spy', 'Simranoberoi', 'ruchi rao', 'Priyaranjan Kumar', 'Vishal Ojha   Bloom Realty', 'shiba durani', 'ProTecDi', 'Kate Brown', 'shikha', 'HinduComrade', 'Pratik Deo', 'g katyan misra', 'InvestmentGuruIndia', 'Ashok mehra', 'Furniture and Fittings Skill Council', 'Dilip Singh', 'FinanzLinksASIA', 'Abhishek Joshi', 'ravi rawat', 'TeamUp Broker Network Channel', 'ACETECH', 'pins', 'Chairsbazaar in', 'cvrlifescience', 'Buynuse', 'Biz of IT Innovations', 'Rakesh Shetty', 'Sahyog College', 'Plant People', 'Sekharbiswas', 'saket', 'Pradnesh Desai', 'mukesh harjani', 'Parag Awasthi', 'mamarahimsalim', 'Horizons Cottages', 'Scarlet Splendour', '', 'sunil prajapati', 'TheMaddy', '', 'Wishkarma Com', 'Onesite Realty', 'Il Rigattiere Dadaista', 'mstk', 'Rizo Khalifa', 'TheMorningStandard', 'Cenmax', 'Trust Bandit', 'sshetty', 'Blanche Horst', 'JE VEE Infrastructure PVT  LTD ', 'whiskeylovinpundit', 'Jignesh Parekh', 'All 101', 'Sudha Blanc', 'Parveen Kader', 'Prince Polo', 'Brendan Rodrigues', 'Raulf', 'TukdeTukdeofTukdeTukde', 'himniserviceapartments', 'MOHAMMED JABIR HUSSAIN SHAIKH', 'mrsubramani', 'Sachin Jawale', 'Chandrashekhar Upadhyay', 'IndiaBusinessQuiz', 'prabhakar', 'Mateen Hafeez', 'LawHak', 'Cat', 'Oni Sing', 'BASF', 'Nil Frando', 'Bright Angles', 'Hardik', 'Amogh Nayak', 'Sudhir', 'alison mccafferty', 'Anand Sanghvi', 'Ankit Sadariya', 'Rashtrapati Bheem', 'Debabrata Mukherjee', '7WD Design Studio', 'Milind Goraksha', 'Hemant Srivastava', 'S Phobia', '', 'Pavani B', 'Nedrick Events', 'Livingetc India', 'Good Governance', 'In Style Woman', 'Lone Crusader 2 0', 'RVAIDYA2000', 'Neelesh Bajaj', 'Sudip Joshi', 'Ahlam Galadari', 'MouthShut com', 'SU Art and Music Histories', 'Jim Stevenson', 'Future World', 'B S Purohit', 'Rizwan Shaikh', 'M Almoula', 'Venzo Wood', 'urban hermit', 'Mihir Bijur', 'Shrikant', 'Priyanka Borpujari', ' pma ', 'Wallpaper ', 'JAGAHA', 'Voice Of Ram', 'Interior Design Addict', 'Tea Lover', 'Ben Waren', 'Myles D Gooding', 'Aliabbas Mundrawala', 'PropCheckup', 'Sukanta Kumar Mishra', 'Premleela Heights', 'Sure Mithas Travel', 'HKTDC', 'Ajay Chaturvedi', 'Dev Chaudhary', 'morphogenesis ', 'Mohammad Iqbal Abid', 'Vishal Vora', 'Navneet sahay', 'Yash Kabra', 'Gobindram Bang', 'Food Cuddle', 'Roberto G  Berlanga', 'Sudhir Parmar', 'myadvtcorner com', 'ApkGK Com', 'John', 'Reena Gupta', 'Armyveternal', 'nilu', 'PAYAL ROHATGI   Team  Bhagwan Ram Bhakts', 'REAL ESTATE CONSULTANT MUMBAI', 'Charles Dsa', 'piyush doshi', 'Baby Llama', 'Kesaria', 'Chaotic Peace AsimSquad', 'AYAZ Y  KHAN  PAPPU ', 'IP', 'Sujoy Dhar', 'astrologerambajijyotish', 'Ambika Bhatt', 'rituparna bharat sarma', 'Mumtaz Rahebar Khan', 'VAYA Fabrics', 'Pratik Bubna', 'PRABHAT DUBE', 'Ruchika Pal Kaur', 'NDTV Profit', 'rajan sen', 'Ishita Joshi', 'Shraddha Pawar', 'India News', 'Pritam Biswas', 'Ram Bhimani', 'Namo Etle Saune Gamo', 'Totes McGoats', 'Anika', 'YourStory', 'askwebm', 'NJ', '', 'Madhuri Bhaduri', 'Kamal Kumar I KEJRIWAL', 'ilika s thapa', 'LatestLY', 'Gustav Sha', 'Samirr Sirr', 'Hardik Shah', 'Manish Bhatia', 'Wasim Akram', 'Bagad Billa  Original ', 'Ashutosh Agarwal', 'cynthia kosciuczyk', 'Post Your Ads Free', 'Antonini Modern Living', 'Abhijit Chatterjee', 'PHP 101', '', 'dhruv', 'Naresh Mintri', 'phirekbaarModisarkar', 'Mike Whitla', 'Apurba Sen', 'Jiten Gajaria', 'Nishith', 'Touroxy ...
# After last cleaning:  {'', 'Food Cupid', 'estudio 3DRz', 'Ishita Chawla', 'Ankit Sadariya', 'Reena Gupta', 'Maakaachar', 'Parveen Kader', 'PAYAL ROHATGI   Team  Bhagwan Ram Bhakts', 'Wasim Akram', 'Revanta Sarabhai', 'Nilesh Shah', 'Cuddles Panda', 'Jason Hayes', 'Hardik', 'PRABHAT DUBE', 'MyOpinionNotConclusion', 'Ashish Sood', 'piyush doshi', 'Omprakash Dubey  Omji ', 'Rizwan Shaikh', 'themrsidey', 'Arvind Pandey', 'Saurabh Mishra', 'renderimage', 'Namo Etle Saune Gamo', 'Ruchika Pal Kaur', 'AYAZ Y  KHAN  PAPPU ', 'Telling It', 'MOHAMMED JABIR HUSSAIN SHAIKH', 'JAGAHA', 'Priyanka Borpujari', 'Biz of IT Innovations', 'Wishkarma Com', 'Rohit Modi', 'cvrlifescience', 'IP', 'Aiswarya Thampy', 'Block me please', 'YourStory', 'Vkrant Kisan Varkute', 'Avoca Travels', 'KM', 'M Almoula', 'Abhishek Joshi', 'Abhijit Chatterjee', 'Shiva Kumar', '42', 'Suma B', 'Chaotic Peace AsimSquad', 'Atul B  Kamothi', 'mstk', 'Vikram Chachra', 'Deepika Narayan Bhardwaj', 'Fibre2Fashion', 'ravi rawat', 'School Memories', 'Future World', 'Pawan Khandelwal', 'JE VEE Infrastructure PVT  LTD ', 'mrsubramani', 'Samirr Sirr', 'Pavani B', 's', 'morphogenesis ', 'Cenmax', 'Samaksh Khanna', 'Luv', 'Rahul Joshi', 'Ishita Joshi', 'Kernig Krafts', 'FashionatingWorld', 'Jiten Gajaria', 'Brendan Rodrigues', 'Rajesh Advani', 'iqbalkhan', 'Knox Himansshu', 'Nuru Karim', 'ameya kadam', 'g katyan misra', 'ruchi rao', 'Manish P Gawde', 'Trust Bandit', 'Chandrashekhar Upadhyay', 'Kaillash K Sharma', 'cyrusyrus', 'NIPU BDIT', 'VAYA Fabrics', 'Dezeen', 'Manuela Baumgartner', 'Chairsbazaar in', 'Christina scott', 'Namit Sharma', 'alison mccafferty', 'Sanjay Panigrahi', 'TheMorningStandard', 'Shree Mangal Murti', 'Sure Mithas Travel', 'Anindita Bhattacharya', 'LatestLY', 'Parag Awasthi', 'Shyam Bhattacharjee', 'Madhuri Bhaduri', 'Nayantara', 'Simon Cook', 'Armyveternal', 'ApkGK Com', 'urban hermit', 'Arvind Iyer', 'Myles D Gooding', 'HinduComrade', 'Mayur Tolia', 'Annie', 'Wallpaper ', 'Dharmendra Pandey', 'OyeCricket com', 'NDTV Profit', 'Chowkidar Perumal pillai', 'Patanjali Bharat', 'Sahyog College', 'sk khurana', 'Sujoy Dhar', 'Sudhir', 'Mike Whitla', 'Gorch Fock', 'Jim Stevenson', 'Pratham Savla', 'Shaandaar SANJAY', 'Juergen Morhard', 'dhruv', 'Totes McGoats', 'Pradnesh Desai', 'HiGuests', 'Bhartendra', 'Prince Polo', 'Avinash Jha', 'mamarahimsalim', 'Priyaranjan Kumar', 'Vinit Kabra', 'myadvtcorner com', 'STUDIO PURPLE', 'Mateen Hafeez', 'Singh Varun', 'Hardik Shah', 'Roshani Shenazz   Empowering Your Life', 'Kkishore', 'Magui', 'Aamir B Shaikh', 'The Little Known', 'Vandana S', 'Jesal Vora', 'SU Art and Music Histories', 'TA Harsh Dixit', 'Garamchai', 'Tanuja Y Rane', 'prabhakar', 'LawHak', 'cynthia kosciuczyk', 'Enjay IT Solutions Ltd', 'Ajay Chaturvedi', 'rajan sen', 'BiggDeals', 'ShaheenBaugKiBilli', 'Ashok mehra', 'phirekbaarModisarkar', 'Stephanie Richards', 'Simranoberoi', 'Jeri Bittner', ' ', 'Debabrata Mukherjee', 'Neelesh Bajaj', 'Deepak Kumar Vasudevan', 'Scarlet Splendour', 'yummraj', 'Manish Bhatia', 'Satish Joshi', 'S Phobia', 'Naresh Mintri', 'Bittlr', 'Piyul Mukherjee', 'Kate Brown', 'B Sethia', 'sshetty', 'shikha', 'Ram Bhimani', 'Tim Hudson', 'Ranjan Patel', 'Half Three', 'Roots   Leisure', 'Sekharbiswas', 'Prashant Sharma', 'Manish76', 'Ashutosh yadav', 'CII Live', 'Post Your Ads Free', 'Ajay Singh', 'Baby Llama', 'Anamika Verma', 'P  R  SANJAI', 'The Incorruptible', 'Gustav Sha', 'Coconut Event', 'Mayank', 'Ben Waren', 'Saeed Valadbaygi', 'Sindhi Chokro', 'Lone Crusader 2 0', 'ANAROCKRetail', 'Voice Of Ram', 'Ambika Bhatt', 'PATCH NYC', 'amit deshpande', 'pins', 'askwebm', ' RC', 'Sanskar Semwal', 'shiba durani', 'TheMaddy', 'Niva', ' DestroyTheAadhaar TwiLightOFTheGODS', 'Arjun Kumar', 'himniserviceapartments', 'Bagad Billa  Original ', 'Madhu Gattani', 'Sota', 'whiskeylovinpundit', 'sunil prajapati', 'StudentUniverse', 'BASF', 'The Vogue Lifestyles', 'Thrilling Travel', 'mukesh harjani', 'Tea Lover', 'Apurba Sen', 'Amar', 'Shraddha Pawar', 'Anto ...
# 134865
# 27950
# --- 10529.598484039307 seconds ---
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:200: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

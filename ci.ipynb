# %% [markdown]
# <a href="https://colab.research.google.com/github/VirtualGoat/Twitter-Data-Mining/blob/master/ci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Accessing the data that has been stored. 
from google.colab import drive
import pickle
# import GetOldTweets3 as got
drive.mount('/content/drive')
DATA_PATH = "/content/drive/My Drive/Colab Notebooks/Internship/Tweet Data/New/Mumbai/Active"
users4=open(DATA_PATH+'/fullupdated.pickle','rb')
real_tweets3=pickle.load(users4)
users4.close()
print(real_tweets3)
lisi=list()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'mmharjani633': 398, 'namanas': 313, 'lawyerhakim': 287, 'KishoreVaid': 283, 'chai2kul': 277, 'Jabalpursafety': 262, 'am_i_anup': 257, 'rigattieredada': 251, 'amarbheenick': 240, 'KetPan': 239, 'Mj180Shiva': 237, 'Sporty_Baba': 234, 'odmag': 224, 'manojgjha': 222, 'mamarahimsalim': 205, 'beachhasaliens': 198, 'rituparnasarm10': 195, 'RuchikaJain89': 192, 'maakaachar': 191, 'AruSharmaTweets': 184, 'CitizenKamran': 182, 'HimjaParekh': 176, 'ishwarsha27': 176, 'Halfthree': 172, 'health_z_wealth': 164, 'prince_man11': 162, 'dastgeerikariw': 161, 'ClarenceWhitti5': 160, 'ermbates': 160, 'VORdotcom': 154, 'avs_mohan': 147, 'PSchwiter': 144, 'MikeDesai': 144, 'VenuSpeak': 143, 'AjitBhaskar8': 143, '3DRz_Studio': 143, 'semubhatt': 141, 'Faisal_A_Latif': 139, 'rvaidya2000': 139, 'AshVerma111': 130, 'Rajeshshen': 129, 'Manvend03129323': 129, 'geetv79': 128, 'halalatan': 127, 'platinumcorp_in': 127, 'sanketrao': 126, 'GauravKPaul': 123, 'ItikaNaik10': 122, 'Vandana45086528': 121, 'SindhiChokroVB': 120, 'VHetal': 120, 'kumarr_raj': 119, 'mrugesh123': 119, 'CatherineDatui4': 118, 'sssaaagar': 116, 'nalinidesai': 116, 'yogesh2165': 116, 'pratikzart': 116, 'adithyav0405': 114, 'yashgandhi66': 113, 'zoinxy': 113, 'SOHINI47247141': 113, 'KesariDhwaj': 112, 'darshanik1': 111, 'Kishan561': 111, 'farpavillians': 110, 'AnkushD65021363': 110, 'jkd18': 110, 'SritikaDhar': 109, 'vishy972': 109, 'lucidillusions_': 109, 'TheChakravartin': 109, 'NishasKhan': 108, 'sudhirgparmar': 107, 'saurabh': 103, 'Tazeen_11': 102, 'Raahi_supergirl': 101, 'shucutiepie': 101, 'PromostylParis': 101, 'goswamimukesh5': 100, 'katranjeet': 99, 'Aishhwaryaa1': 99, 'dhanashree0110': 96, 'cheerscobberta': 96, 'rdkriplani': 93, 'Anupbhatia7': 93, 'GobindramBang3': 91, 'adt007ad': 89, 'AffanViews': 88, 'SujnanNayak': 88, 'LinaSCC': 87, 'porwal_sarika': 87, 'vinitbhavi': 87, 'NikitaBobade3': 86, 'AshwinR94': 86, 'nirmalapairtel': 86, 'ZeeMa1ik': 85, 'ahmadziakhan1': 85, 'pulakkk': 84, 'SunBunAurPun': 84, 'bachPunn': 83, 'Rubalsandhu5': 82, 'cbdhage': 82, 'anvitanath': 81, 'Hosalikar_KS': 81, 'ShamaSrujan': 81, 'NayyarSanjeev': 80, 'ali105hassan': 80, 'ravihanda': 79, 'go_mohan': 78, 'TheAxiom1': 77, 'Equiideas09': 77, 'VivekAN4': 77, 'carlos04667': 77, 'DramaTomic': 77, 'ajaysahoo1981': 76, 'FekuBuster': 76, 'RAJESHK23_': 76, 'SultanMd29': 76, 'bavlichhori': 76, 'NATRAJSHETTY': 75, 'varshasinghs': 75, 'MoveOnLifee': 75, 'JAGAHA_CRE': 75, 'AmitSKumar81': 74, 'VoiceOfAxom': 74, 'arian_earthling': 73, 'manojkrs29': 73, 'Hostwriter': 73, 'KM7869': 72, 'SrSrinivasamu': 71, 'saxenavipul64': 71, 'teodranik': 71, 'yellowtrace': 71, 'quidtask': 69, 'DildaarSid': 69, 'bhavesh_khona': 69, 'PWNeha': 69, 'aptenco': 69, 'CIIEvents': 68, 'HarishMurthy7': 68, 'Usha_Srivastava': 68, 'vipul_kp': 68, 'shah_1972': 68, 'Kamal_destiny': 67, 'pksrivastava6': 67, 'nimeshscnbc': 66, 'anuppandey': 66, 'Tanraj58': 66, 'poonam_216': 66, '2NMPConcept': 66, 'ankibn': 66, 'aneesinha': 65, 'Antoniniml': 65, 'HemanshuJoshi3': 64, 'immymalik2010': 64, 'DBTVLive': 64, 'TOIAhmedabad': 63, 'vineet_rai': 63, 'FarziLogic': 62, 'SirYuzvendra': 62, 'Khushnaaz26': 62, 'Hariram208Ram': 62, 'kanakia_spaces': 61, 'cool_bindra': 61, 'kwt_sandeep': 61, 'ConfuseForever': 61, 'PhalinShah': 61, 'AmmarAshraf': 60, 'SAP_APJ': 59, 'RAJNEESHAGRAWA1': 59, 'indu_19__': 59, 'KapurMeenakshi': 58, 'AirlineGuy3': 58, 'yashvirana1': 58, 'vishthecomic': 56, 'RajeshAdvani13': 56, 'metromoghli': 56, 'hiyer': 56, 'wandering_monk': 55, 'pratikpanchal06': 55, 'kartik73': 55, 'creativeirfan': 55, 'avianlifestyles': 55, 'luckyfresh': 54, 'Somvanshi76': 54, 'jagy_rav': 54, 'mihirm123': 54, 'jonsonbill': 54, 'PSD_XHTML': 53, 'KhaleejMag': 53, 'hazratbilli': 53, 'lionbhai': 53, 'Punishe39696428': 53, 'jeonkookieandme': 53, 'Jigs2704': 53, 'sundar_iyer0490': 53, 'VipulV2304': 53, 'simplysud': 52, 'adspostinghere': 52, 'KJVchaitanya': 52, 'sukanyaiyer2': 52, 'hamidsanaPTI': 51, 'BorahBedabrata': 51, 'The_Wa_Na': 50, 'desimarthastew': 50, 'talktosanja ...

# %%
import tweepy

consumer_key=''
consumer_secret= ''
access_token=''
access_token_secret=''
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
import re
j=0
d=dict()
for i,k in real_tweets3.items():
    print(j)

    ci=list()
    j=j+1
    try:
      u=api.get_user(i)
      # print("Crawling account:", u.screen_name)
      stat=u.description
      lst = re.findall('\S+@\S+', stat)
      ph = re.findall('[789]\d{9}', stat)
      
      if len(lst>0):
        print(lst)
        ci.append(lst)
      if len(ph>0):
        print(ph)
        ci.append(ph)

      if len(lst)>0 or len(ph)>0:
        d[i]=ci
      
    except:
      continue
    print(j)

# print("Extracted Usernames: ",pname)
# Out:
# 0
# 1
# 2
# 3
